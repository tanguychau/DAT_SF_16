# %% [markdown]
# # Homework 2 - Tanguy Chau

# %% [markdown]
# I want to crawl the Google News website and download all relevant news headline

# %%
import json
import urllib

results = json.load(urllib.urlopen("https://www.kimonolabs.com/api/ce2emruo?apikey=J2SXpD3IZWCVgO4XWL3Q7wDLy2NuYtYd"))

# %%
results
# Out:
# {u'count': 76,
#  u'frequency': u'Manual Crawl',
#  u'lastrunstatus': u'success',
#  u'name': u'googlenews',
#  u'newdata': True,
#  u'results': {u'collection1': [{u'description': u'US president Barack Obama has launched an intense lobbying campaign to convince Congress to approve a nuclear deal with Iran, warning that rejecting it could lead to another war in the Middle East.',
#     u'index': 1,
#     u'title': {u'href': u'http://www.abc.net.au/news/2015-08-06/obama-dials-up-the-pressure-on-us-congress-to-pass-iran-deal/6676172',
#      u'text': u'Barack Obama increases pressure on US Congress to pass Iran nuclear deal'},
#     u'url': u'https://news.google.com/'},
#    {u'description': u'Experts confirmed a wing flap found on an island in the Indian Ocean belongs to missing Malaysia Airlines Flight 370, Malaysian Prime Minister Najib Razak said Wednesday.',
#     u'index': 2,
# ...

# %%
print results['title']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-6-67c8c0d9aa82> in <module>()
# ----> 1 print results['title']
#
# KeyError: 'title'
